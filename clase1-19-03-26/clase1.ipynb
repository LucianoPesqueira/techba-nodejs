# %% [markdown]
# ## Instalación y Configuración de Node JS y NPM

# %% [markdown]
# * Sitio oficial de Node Js: https://nodejs.org
#     - verificar la version de node instalada: **node -v**
#     - verificar la version de npm instalada: **npm -v**
